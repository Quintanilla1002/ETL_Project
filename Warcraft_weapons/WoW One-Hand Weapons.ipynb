# %% [markdown]
# # WoW One-Hand Weapons

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#read the One-Hand Weapons csv
onehand_file = "Resources/One-Hand.csv"
onehand_df=pd.read_csv(onehand_file)
onehand_df.head()
# Out:
#      agi  agiint  agistr  agistrint  armor classes  cooldown  corruption  \
# 0  118.0     NaN     NaN        NaN    NaN     NaN       NaN         NaN
# 1  118.0     NaN     NaN        NaN    NaN     NaN       NaN         NaN
# 2    NaN     NaN     NaN        NaN    NaN     NaN       NaN         NaN
# 3    NaN     NaN     NaN        NaN    NaN     NaN       NaN         NaN
# 4    NaN     NaN     NaN        NaN    NaN     NaN       NaN         NaN
#
#    critstrkrtng  dmg  ...  rgdcritstrkrtng  slotbak  socket1  socket2  \
# 0          59.0  NaN  ...              NaN     13.0      NaN      NaN
# 1           NaN  NaN  ...              NaN     13.0      NaN      NaN
# 2           NaN  NaN  ...              NaN     13.0      NaN      NaN
# 3           NaN  NaN  ...              NaN     13.0      NaN      NaN
# 4           NaN  NaN  ...              NaN     13.0      NaN      NaN
#
#    socket3  speed  splpwr    sta    str  versatility
# 0      NaN    2.6     NaN  178.0    NaN         46.0
# 1      NaN    1.8     NaN  178.0    NaN          NaN
# 2      NaN    2.6     NaN    NaN    3.0          NaN
# 3      NaN    2.6     NaN  178.0    NaN         75.0
# 4      NaN    2.6     NaN  178.0  118.0         36.0
#
# [5 rows x 40 columns]

# %%
#Clean the data frame to have only relevant stats/columns
clean_onehand_df=onehand_df[["name_enus", "quality", "dmgmin1", "dmgmax1", "dps", "mlespeed"]]
clean_onehand_df.head()
#Rename Columns
onehand_renamed=clean_onehand_df.rename(columns={"name_enus": "name",
                                       "quality": "quality",
                                       "dmgmin1": "min_damage",
                                      "dmgmax1": "max_damage",
                                      "dps": "dps",
                                      "mlespeed": "weapon_speed_in_seconds"})
#drop NaN columns as these are not weapons and irrelevant to the dataset if they do not have a damage value
onehand_renamed=onehand_renamed.dropna(how='any')
onehand_renamed.head()
# Out:
#                  name   quality  min_damage  max_damage     dps  \
# 0   Cold Forged Blade      Epic       262.0       438.0  134.77
# 1     The Lobotomizer      Epic       181.0       303.0  134.70
# 2               Stung  Uncommon         3.0         5.0    1.56
# 3  Cold Forged Hammer      Epic       153.0       197.0   67.36
# 4           Frostbite      Epic       227.0       473.0  134.76
#
#    weapon_speed_in_seconds
# 0                      2.6
# 1                      1.8
# 2                      2.6
# 3                      2.6
# 4                      2.6

# %%
#Create Connection to PgAdmin
rds_connection_string = "postgres:postgres@localhost:5432/Warcraft Weapons"
engine = create_engine(f'postgresql://{rds_connection_string}')

#Verify table names
engine.table_names()
# Out:
# ['onehand_weapons',
#  'mh_weapons',
#  'oh_weapons',
#  'ranged_weapons',
#  'twoh_weapons',
#  'held_oh']

# %%
#Load Data Frames in SQL Database
onehand_renamed.to_sql(name='onehand_weapons', con=engine, if_exists='append', index=False)
