# %% [markdown]
# # WoW Off-Hand Weapons

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#read the Off-Hand Weapons csv
oh_file = "Resources/Off Hand.csv"
oh_df=pd.read_csv(oh_file)
oh_df.head()
# Out:
#    agi  armor classes  cooldown  critstrkrtng  dmg  dmgmax1  dmgmin1  dps  \
# 0  NaN    NaN     NaN       NaN           NaN  3.0      NaN      NaN  NaN
# 1  NaN    NaN     NaN  0.000278           NaN  NaN      NaN      NaN  NaN
# 2  NaN    NaN     NaN       NaN           NaN  3.0      NaN      NaN  NaN
# 3  NaN    NaN     NaN       NaN           NaN  NaN      NaN      NaN  NaN
# 4  NaN    NaN     NaN       NaN           NaN  4.0      NaN      NaN  NaN
#
#    dura  ...  nsockets  pvppower  quality  reqlevel  slotbak  socket1  speed  \
# 0   NaN  ...       NaN       NaN   Common       5.0      NaN      NaN    NaN
# 1   NaN  ...       NaN       NaN   Common       5.0      NaN      NaN    NaN
# 2   NaN  ...       NaN       NaN   Common       5.0      NaN      NaN    NaN
# 3   NaN  ...       NaN       NaN     Rare       NaN      NaN      NaN    NaN
# 4   NaN  ...       NaN       NaN   Common      15.0      NaN      NaN    NaN
#
#   sta  str  versatility
# 0 NaN  NaN          NaN
# ...

# %%
#Clean the data frame to have only relevant stats/columns
clean_oh_df=oh_df[["name_enus", "quality", "dmgmin1", "dmgmax1", "dps", "mlespeed"]]
clean_oh_df.head()
#Rename Columns
oh_renamed=clean_oh_df.rename(columns={"name_enus": "Name",
                                       "quality": "Quality",
                                       "dmgmin1": "Minumum Damage",
                                      "dmgmax1": "Maximum Damage",
                                      "dps": "Damage Per Second",
                                      "mlespeed": "Weapon Speed (in Seconds)"})
oh_renamed
#drop NaN columns as these are not weapons and irrelevant to the dataset if they do not have a damage value
oh_renamed=oh_renamed.dropna(how='any')
oh_renamed.head()
# Out:
#                           Name    Quality  Minumum Damage  Maximum Damage  \
# 27  Dal'Rend's Tribal Guardian       Rare            16.0            28.0
# 29        High Warlord's Razor       Epic            11.0            20.0
# 30       Warglaive of Azzinoth  Legendary            23.0            39.0
# 32       Warglaive of Azzinoth  Legendary            23.0            39.0
# 36         Shadowstalking Shiv   Uncommon            17.0            30.0
#
#     Damage Per Second  Weapon Speed (in Seconds)
# 27               8.65                        2.6
# 29               8.82                        1.8
# 30              11.98                        2.6
# 32              11.98                        2.6
# 36              13.25                        1.8
